# %% [markdown]
# <a href="https://colab.research.google.com/github/minseokey/Data_Science/blob/main/DataScience13_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import requests
import networkx as nx

# %%
with open("example_index","wb")as f:
  r = requests.get("http://webdatacommons.org/hyperlinkgraph/data/example_index")
  f.write(r.content)
  f.close()

with open("example_arcs", "wb") as f:
 r = requests.get("http://webdatacommons.org/hyperlinkgraph/data/example_arcs")
 f.write(r.content)
 f.close()

# %%
 nodes = np.loadtxt("example_index",dtype=object)[:,0] # 텍스트가 포함되어 있으니 not int
#  num_nodes = nodes.shape[0]
#  num_nodes

 edges = np.loadtxt("example_arcs", dtype=int)
#  num_edges = edges.shape[0]
#  num_edges

# %%
graph = nx.DiGraph()

plt.figure(dpi=300)
G = nx.DiGraph()
for e in edges:
 G.add_edge(nodes[e[0]], nodes[e[1]])
pos = nx.spring_layout(G, k=1, iterations=200)
nx.draw(G, pos, with_labels=True, node_size=10, font_size=5, width=0.1)
