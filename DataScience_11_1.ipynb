# %% [markdown]
# <a href="https://colab.research.google.com/github/minseokey/Data_Science/blob/main/DataScience_11_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = pd.read_csv("iris.data",names=['a','b','c','d','label'])
data
# Out:
#        a    b    c    d           label
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data = []

for line in open('iris.data','r'):
  raw = line.split(",")
  x = [float(r) for r in raw[:4]]
  y = raw[4].strip()
  data.append((x,y))
data
# Out:
# [([5.1, 3.5, 1.4, 0.2], 'Iris-setosa'),
#  ([4.9, 3.0, 1.4, 0.2], 'Iris-setosa'),
#  ([4.7, 3.2, 1.3, 0.2], 'Iris-setosa'),
#  ([4.6, 3.1, 1.5, 0.2], 'Iris-setosa'),
#  ([5.0, 3.6, 1.4, 0.2], 'Iris-setosa'),
#  ([5.4, 3.9, 1.7, 0.4], 'Iris-setosa'),
#  ([4.6, 3.4, 1.4, 0.3], 'Iris-setosa'),
#  ([5.0, 3.4, 1.5, 0.2], 'Iris-setosa'),
#  ([4.4, 2.9, 1.4, 0.2], 'Iris-setosa'),
#  ([4.9, 3.1, 1.5, 0.1], 'Iris-setosa'),
#  ([5.4, 3.7, 1.5, 0.2], 'Iris-setosa'),
#  ([4.8, 3.4, 1.6, 0.2], 'Iris-setosa'),
#  ([4.8, 3.0, 1.4, 0.1], 'Iris-setosa'),
#  ([4.3, 3.0, 1.1, 0.1], 'Iris-setosa'),
#  ([5.8, 4.0, 1.2, 0.2], 'Iris-setosa'),
#  ([5.7, 4.4, 1.5, 0.4], 'Iris-setosa'),
#  ([5.4, 3.9, 1.3, 0.4], 'Iris-setosa'),
#  ([5.1, 3.5, 1.4, 0.3], 'Iris-setosa'),
#  ([5.7, 3.8, 1.7, 0.3], 'Iris-setosa'),
#  ([5.1, 3.8, 1.5, 0.3], 'Iris-setosa'),
#  ([5.4, 3.4, 1.7, 0.2], 'Iris-setosa'),
#  ([5.1, 3.7, 1.5, 0.4], 'Iris-setosa'),
#  ([4.6, 3.6, 1.0, 0.2], 'Iris-setosa'),
# ...

# %%
import matplotlib.pyplot as plt
X = []
Y = []

for v,l in data:
  X.append(v[0])
  Y.append(v[1])
classes = set(l for v,l in data)
print(classes)

plt.scatter(X,Y,alpha = 0.5)
plt.show()
# Out:
# {'Iris-versicolor', 'Iris-virginica', 'Iris-setosa'}

# %%
classes = {l:[] for v,l in data}
for v,l in data:
  classes[l].append(v)

print(classes)
for c, c_data in classes.items():
  X=[]
  Y=[]
  for v in c_data:
    X.append(v[2])
    Y.append(v[3])
  plt.scatter(X,Y,alpha = 0.5)
plt.show()
# Out:
# {'Iris-setosa': [[5.1, 3.5, 1.4, 0.2], [4.9, 3.0, 1.4, 0.2], [4.7, 3.2, 1.3, 0.2], [4.6, 3.1, 1.5, 0.2], [5.0, 3.6, 1.4, 0.2], [5.4, 3.9, 1.7, 0.4], [4.6, 3.4, 1.4, 0.3], [5.0, 3.4, 1.5, 0.2], [4.4, 2.9, 1.4, 0.2], [4.9, 3.1, 1.5, 0.1], [5.4, 3.7, 1.5, 0.2], [4.8, 3.4, 1.6, 0.2], [4.8, 3.0, 1.4, 0.1], [4.3, 3.0, 1.1, 0.1], [5.8, 4.0, 1.2, 0.2], [5.7, 4.4, 1.5, 0.4], [5.4, 3.9, 1.3, 0.4], [5.1, 3.5, 1.4, 0.3], [5.7, 3.8, 1.7, 0.3], [5.1, 3.8, 1.5, 0.3], [5.4, 3.4, 1.7, 0.2], [5.1, 3.7, 1.5, 0.4], [4.6, 3.6, 1.0, 0.2], [5.1, 3.3, 1.7, 0.5], [4.8, 3.4, 1.9, 0.2], [5.0, 3.0, 1.6, 0.2], [5.0, 3.4, 1.6, 0.4], [5.2, 3.5, 1.5, 0.2], [5.2, 3.4, 1.4, 0.2], [4.7, 3.2, 1.6, 0.2], [4.8, 3.1, 1.6, 0.2], [5.4, 3.4, 1.5, 0.4], [5.2, 4.1, 1.5, 0.1], [5.5, 4.2, 1.4, 0.2], [4.9, 3.1, 1.5, 0.1], [5.0, 3.2, 1.2, 0.2], [5.5, 3.5, 1.3, 0.2], [4.9, 3.1, 1.5, 0.1], [4.4, 3.0, 1.3, 0.2], [5.1, 3.4, 1.5, 0.2], [5.0, 3.5, 1.3, 0.3], [4.5, 2.3, 1.3, 0.3], [4.4, 3.2, 1.3, 0.2], [5.0, 3.5, 1.6, 0.6], [5.1, 3.8, 1.
# ...

# %%
def distance(a,b):
  s = 0
  for x,y in zip(a,b):
    s += (x-y)**2
  
  return s**0.5

# %%
# from collections import Counter
# def knn_classify(k,query,data):
#   dist =  [(distance(query,v),l) for v,l in data]  
#   dist.sort()
#   topk = dist[:k]
#   cnts = Counter(l for d,l in topk)
#   return cnts.most_common(1)[0][0]

# k = 3
# res = knn_classify(k,[6.4,2.8,5.6,2.2],data)

# res

# %%
from collections import Counter

def knn_classify(k,query,data):

  while True:
    topk = sorted((distance(query,v),l)for v,l in data)[:k]
    cnts = Counter(l for d,l in topk)
    mc = cnts.most_common(2)
    if len(cnts) == 1 or mc[0][1] != mc[1][1]:
      break
    else:
      k -= 1
  
  return cnts.most_common(1)[0][0]

k = 3
res = knn_classify(k,[6.4,2.8,5.6,2.2],data)
print(res)
# Out:
# Iris-virginica

# %%
from matplotlib import pyplot as plt

x = []
y = []
for k in range(1,50):
  n_correct = 0
  n_incorrect = 0
  for i ,(v,l) in enumerate(data):
    new_data = []
    for j,d in enumerate(data):
      if i == j: continue
      new_data.append(d)
    ans = knn_classify(k,v,new_data)
    if l == ans:
      n_correct += 1
    else:
      n_incorrect += 1

  accuracy = n_correct/(n_correct+n_incorrect)
  x.append(k)
  y.append(accuracy)
  print(accuracy)

plt.plot(x,y)
plt.show()
# Out:
# 0.96
# 0.96
# 0.96
# 0.96
# 0.9666666666666667
# 0.9666666666666667
# 0.9666666666666667
# 0.9666666666666667
# 0.9666666666666667
# 0.9666666666666667
# 0.9733333333333334
# 0.9733333333333334
# 0.9666666666666667
# 0.9666666666666667
# 0.9733333333333334
# 0.9733333333333334
# 0.9733333333333334
# 0.9733333333333334
# 0.98
# 0.98
# 0.98
# 0.98
# 0.9666666666666667
# 0.9666666666666667
# 0.9666666666666667
# 0.9666666666666667
# 0.9666666666666667
# 0.9666666666666667
# 0.9533333333333334
# 0.9533333333333334
# 0.9466666666666667
# 0.9466666666666667
# 0.9533333333333334
# 0.9533333333333334
# 0.9533333333333334
# 0.9533333333333334
# 0.9466666666666667
# 0.9466666666666667
# 0.9533333333333334
# 0.9533333333333334
# 0.9466666666666667
# 0.9466666666666667
# 0.94
# 0.94
# 0.9466666666666667
# 0.9466666666666667
# 0.9466666666666667
# 0.9466666666666667
# 0.94
